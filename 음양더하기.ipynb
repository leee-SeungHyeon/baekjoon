# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(absolutes, signs):
    
    sum = 0
    
    for ab, si in zip(absolutes, signs):
        if si:
            sum += ab
        else:
            sum -= ab

    return sum
