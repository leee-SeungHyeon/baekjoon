# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())

st = []
for _ in range(n):
    sss = input()
    st.append(sss)
    
for i in range(len(st)):
    print('{}. {}'.format(i+1, st[i]))
# Out:
# 1. Lionel Cosgrove
# 2. Alice
# 3. Columbus and Tallahassee
# 4. Shaun and Ed
# 5. Fido
