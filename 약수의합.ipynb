# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 5

sum = 0

for i in range(1,n+1):
    if n % i == 0:
        sum += i
        
print(sum)
# Out:
# 6

# %%
def solution(n):
    sum = 0

    for i in range(1,n+1):
        if n % i == 0:
            sum += i
    
    return sum
