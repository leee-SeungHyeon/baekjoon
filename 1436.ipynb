# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())

count = 1
start = 666

while True:
    if n == count:
        break
    start += 1
    
    if '666' in str(start):
        count += 1
        
print(start)
# Out:
# 1666
