# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(my_string, queries):
    for a,b in queries:
        if a != 0:
            my_string = my_string[:a] + my_string[b:a-1:-1] + my_string[b+1:]
        else:
            my_string = my_string[b:a:-1] + my_string[:a+1] + my_string[b+1:]
    return my_string
# Out:
# 'programmers'
