# %% [markdown]
# ![image.png](attachment:image.png)

# %%
str = input()

for i in str:
    if True == i.isupper():
        print(i.lower(), end='')
        
    elif True == i.islower():
        print(i.upper(), end='')
