# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
N = int(input())
F = int(input())

# 마지막 두 자리를 00부터 99까지 변경하여 확인
for i in range(100):
    new_N = N // 100 * 100 + i  # 마지막 두 자리를 변경한 값
    if new_N % F == 0:  # 변경한 값이 F로 나누어 떨어지는 경우
        print(str(i).zfill(2))  # 앞에 0을 추가하여 두 자리로 출력
        break
# Out:
# 15
