# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(s):
    
    s1 = s.lower()
    p1 = s1.count('p')
    y1 = s1.count('y')

    if p1==y1:
        return True
    elif p1==y1==0:
        return True
    else:
        return False
