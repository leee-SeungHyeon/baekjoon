# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = int(input())

for i in range(N):
    r, s = input().split()
    
    for j in range(len(s)):
        print(s[j]*int(r), end='')
    print()
# Out:
# aaabbbvvv
# /////hhhhhtttttppppp
