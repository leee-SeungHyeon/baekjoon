# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())

n_list = list(map(int, input().split()))

c = 0

for x in n_list:
    for i in range(2, x+1):
        if x%i == 0:
            if x == i:
                c += 1
            break        
print(c)
# Out:
# 3
