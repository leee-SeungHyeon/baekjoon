# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())

num_list = []

for _ in range(n):
    a = list(map(int, input().split()))
    
    num_list.append(a)

for i in sorted(num_list):
    for j in i:
        print(j, end=' ')
    print('')
# Out:
# 1 -1
# 1 1
# 2 2
# 3 3
# 3 4
