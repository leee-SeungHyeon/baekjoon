# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
n = int(input())

num = list(map(int, input().split()))

y = 0
m = 0

for i in num:
    y += (i//30+1) * 10
    m += (i//60+1) * 15

if y==m:
    print('Y M',y)
elif y>m:
    print('M',m)
elif y<m:
    print('Y',y)
# Out:
# M 45
