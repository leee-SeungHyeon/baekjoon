# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
n1 = set(map(int, input().split()))
m = int(input())
m1 = list(map(int, input().split()))

for num in m1:
    print(1) if num in n1 else print(0)
# Out:
# 1
# 1
# 0
# 0
# 1
