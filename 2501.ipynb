# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m , k = map(int, input().split())

nums = []

for i in range(1,m+1):
    if m%i == 0:
        nums.append(i)
        
if len(nums) < k:
    print(0)
    
elif nums[k-1]:
    print(nums[k-1])
# Out:
# 1
