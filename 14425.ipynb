# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m, s = map(int, input().split())

count = 0
arr = dict()

for _ in range(m):
    m1 = input()
    arr[m1] = True
    
for _ in range(s):
    word = input()
    if word in arr.keys():
        count += 1

print(count)
# Out:
# 4
