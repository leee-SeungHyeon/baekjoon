# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m = int(input())

dic =dict()

for _ in range(m):
    name, inout = input().split()
    
    if inout == 'enter':
        dic[name] = inout 
    else:
        del dic[name]

dic1 = sorted(dic.keys(), reverse=True)

for i in dic1:
    print(i)
# Out:
# Askar
# Artem
