# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num_list = [1,2,3,4,5,6,7,8]

re_numlist = [8,7,6,5,4,3,2,1]

list(re_numlist)

nnn = list(map(int, input().split()))

if nnn == num_list:
    print('ascending')
elif nnn == re_numlist:
    print('descending')
else:
    print('mixed')
# Out:
# ascending
