# %% [markdown]
# ![image.png](attachment:image.png)

# %%
while True:
    n, m = map(int, input().split())
    
    if n == 0 or m == 0:
        break
    elif n//m == 0:
        print('factor')
    elif n%m == 0:
        print('multiple')
    elif n%m != 0:
        print('neither')
# Out:
# factor
# multiple
# neither

# %%
8%16
# Out:
# 8
