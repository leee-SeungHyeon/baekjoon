# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 123
n = str(n)

sum = 0

for i in range(len(n)):
    sum += int(n[i])
sum
# Out:
# 6

# %%
def solution(n):
    n = str(n)

    sum = 0

    for i in range(len(n)):
        sum += int(n[i])

    return sum
