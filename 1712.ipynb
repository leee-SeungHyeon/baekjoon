# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
a, b, c = map(int, input().split())

if b >= c:
    print(-1)

else:
    n = a//(c - b) + 1
    print(n)
# Out:
# 2100000001
