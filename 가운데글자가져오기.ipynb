# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(s):
    
    if len(s) % 2 == 0:
        if len(s) == 2:
            return s
        else:
            return s[int(len(s)/2)-1:int(len(s)/2)+1]
        
    else:
        return s[int(len(s)/2)]
