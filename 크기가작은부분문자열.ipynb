# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(t, p):
    answer = []
    for i in range(len(t)-len(p)+1):
        answer.append(int(t[i:i+len(p)]))
        
    count = 0
    
    for i in answer:
        if int(i) <= int(p):
            count += 1
        
    return count
