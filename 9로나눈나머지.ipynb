# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(number):
    number = int(number)
    answer = number % 9
    
    return answer

# %%
def solution(number):
    return int(number) % 9
