# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
m = int(input())

num = []

for x in range(n,m+1):
    for i in range(2, x+1):
        if x%i == 0:
            if x == i:
                num.append(x)
            break        
if len(num) == 0:
    print(-1)
else: 
    print(sum(num))
    print(min(num))
# Out:
# 620
# 61
