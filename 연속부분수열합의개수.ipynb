# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def solution(elements):
    
    result = set()
 
    element2 = elements * 2
    # [7, 9, 1, 1, 4, 7, 9, 1, 1, 4]
    
    for i in range(len(elements)):
        for j in range(len(elements)):
            result.add(sum(element2[j:j+i+1]))
    
    return len(result)
