# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(n):
    num = 1
    
    while num**2 <= n:
        if num**2 == n:
            return (num+1)**2
        else:
            num +=1
    return -1
