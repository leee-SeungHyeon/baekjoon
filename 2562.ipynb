# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = 0
for i in range(9):
    a = int(input())    
    if a > num:
        num = a
        idx = i+1

print(num)
print(idx)
# Out:
# 85
# 8

# %% [markdown]
# - 위 과정처럼 풀었지만 틀렸음
# - list를 사용해서 푸는 것이라고 예상했는데, 결국 맞았음
# - 근데 위에도 맞는거긴 한데 왜 틀린거지? 비효율적이라서 그런가

# %%
number = [int(input()) for _ in range(9)]
    
print(max(number))
print(number.index(max(number))+1)
# Out:
# 85
# 8
