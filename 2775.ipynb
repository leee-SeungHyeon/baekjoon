# %% [markdown]
# ![image.png](attachment:image.png)

# %%
T = int(input())

for i in range(T):
    k = int(input())
    n = int(input())
    
    apt = [i for i in range(1,n+1)]
    
    for i in range(k): #층
        for j in range(1,n): #호수
            apt[j] += apt[j-1]
            
    print(apt[-1])
# Out:
# 6
# 10
