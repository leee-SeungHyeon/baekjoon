# %% [markdown]
# ![image.png](attachment:image.png)

# %%
words = [input() for i in range(5)]

# %%
words
# Out:
# ['AABCDD', 'afzz', '09121', 'a8EWg6', 'P5h3kx']

# %%
words = [input() for i in range(5)]

for j in range(15): #5
    for i in range(5): #6 4 5 6 6     
        if j < len(words[i]) :
            print(words[i][j],end='')
# Out:
# Aa0aPAf985Bz1EhCz2W3D1gkD6x
