# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(food):
    answer = ''

    for i in range(1,len(food)):
        aa = food[i] // 2
        if  food[i] // 2 >= 1:
            answer += f'{i}'* aa

    answer_ = answer[::-1]

    a1 = answer + '0' + answer_
    
    return a1
