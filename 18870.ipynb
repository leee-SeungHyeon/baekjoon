# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 내 풀이(시간초과)

# %%
m = int(input())

num_list = list(map(int,input().split()))

num_list1 = sorted(set(num_list))

for i in num_list:
    print(num_list1.index(i), end=' ')
# Out:
# 2 3 0 3 1

# %%
m = int(input())

num_list = list(map(int,input().split()))

num_list1 = sorted(set(num_list))

dic = {num_list1[i]: i for i in range(len(num_list1))}

for i in num_list:
    print(dic[i], end=' ')
# Out:
# 2 3 0 3 1

# %% [markdown]
# - 컴퓨터 풀이

# %%
import sys

input = sys.stdin.readline

n = int(input())
arr = list(map(int, input().split()))

arr2 = sorted(list(set(arr)))
dic = {arr2[i] : i for i in range(len(arr2))}
for i in arr:
    print(dic[i], end = ' ')

# %% [markdown]
# - 나는 왜이렇게 한국말을 이해를 못하는지 모르겠다.. 책을 많이 읽어야겠다..
# - 그리고 이런 문제의 경우 dic를 만들어서 찾는것이 시간복잡도면에서 효율적인것을 확인하였다.
