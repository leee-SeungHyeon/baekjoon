# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ls = sorted(list(map(int, input().split())))
if ls[0] + ls[1] > ls[2]:
    print(sum(ls))
else:
    print((ls[0] + ls[1]) * 2 - 1) #작으면 작은 두 수의 합의 두배에서 1을 뺀 값을 출력

# %% [markdown]
# - 삼각형의 공식을 알아야 풀 수 있는 문제
#     - 작은 두 변의 길이의 합이 제일 긴 변의 길이보다 커야 된다
