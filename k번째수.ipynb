# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(array, commands):
    
    results = []
    
    for command in commands:
        i = command[0]
        j = command[1]
        k = command[2]
        
        tmp = array[i-1:j]
        
        tmp.sort()
        
        results.append(tmp[k-1])
        
    
    answer = []
    return results
