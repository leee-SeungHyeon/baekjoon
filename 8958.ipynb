# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m = int(input())

for i in range(m):
    quiz = input()
    
    score = 0
    combo = 0
    
    for ans in quiz:
        if ans =='O':
            combo += 1
            score += combo
        else:
            combo = 0
    
    print(score)
# Out:
# 10
# 9
# 7
# 55
# 30
