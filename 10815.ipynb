# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())

num1 = list(map(int, input().split()))

m = int(input())

num2 = list(map(int, input().split()))

dic = {}

for i in num2:
    dic[i] = 0
    
for i in num1:
    if i in dic:
        dic[i] = 1
        
for i in dic:
    print(dic[i] , end=' ')
# Out:
# 1 0 0 1 1 0 0 1
