# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(number, n, m):
    if number%n == 0 and number%m == 0:
        return 1
    else:
        return 0

# %%
solution(60,2,3)
# Out:
# 1

# %%
solution(55,10,5)
# Out:
# 0
