# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# int(변환할string, n진법)

# %%
n, b = input().split()
print(int(n,int(b)))
# Out:
# 60466175

# %%
print(int('AXAXS',int(36)))
# Out:
# 18349984

# %% [markdown]
# - 이 문제는 아예 몰랐다. 어떻게 할지 조차 막막했는데, 인터넷을 보니 int를 활용하면 바로 바꿀 수 있는것을 알게 되었다.
