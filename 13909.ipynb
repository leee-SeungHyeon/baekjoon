# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = int(input())

print(int(num**0.5))
# Out:
# 4

# %%
1  111111111

2  10 1010101

3  100 011100

4  1001 11110

5  10010 1110

6  100100 110

7  1001000 10

8  10010000 0

9  100100001
