# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(my_strings, parts):

    result = ''

    for string, position in zip(my_strings, parts):
        result = result + string[position[0]:position[1]+1]

    return result
# Out:
# programmers
