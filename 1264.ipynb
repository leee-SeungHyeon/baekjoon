# %% [markdown]
# ![image.png](attachment:image.png)

# %%
while True:
    c = 0
    st = input().lower()
    
    if st == '#':
        break
    
    for i in st:
        if i in ['a','e','i','o','u']:
            c += 1
            
    print(c)
# Out:
# 7
# 14
# 9
