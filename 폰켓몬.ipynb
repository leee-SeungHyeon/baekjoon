# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def solution(nums):
    
    max_ = len(nums)/2
    
    nums_ = len(set(nums))
    
    if max_ == nums_:
        return nums_
    elif max_ > nums_:
        return nums_
    else:
        return max_
