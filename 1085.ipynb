# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x, y, w, h = map(int, input().split())

print(min(x, y, w-x, h-y))
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)
# - x,y에서 어느점으로 가야 가장 최소로 가는지 구하는 문제임
