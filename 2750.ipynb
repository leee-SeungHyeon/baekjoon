# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m = int(input())
num_list = []
for _ in range(m):
    num = int(input())
    num_list.append(num)

num_list.sort()    

for i in num_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
