# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(numLog):
    
    dictt = {1:'w', -1:'s', 10:'d', -10:'a'}

    result = ''
    a = 0
    
    for i in range(1,len(numLog)):
        a = numLog[i] - numLog[i-1]
    
        result += dictt[a]
    
    return result
# Out:
# wsdawsdassw
