# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a , b = list(map(str, input().split()))

a_ = 0
for i in a:
    a_ += int(i)
    
b_ = 0
for i in b:
    b_ += int(i)
    
print(a_*b_)
# Out:
# 54
