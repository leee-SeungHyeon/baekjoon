# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 118372

number = [int(i) for i in str(n)]

sum = 0

for i in range(len(number)):
    sum += max(number)
    number = number.pop(max(number))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-9245719408bd> in <module>
#       7 for i in range(len(number)):
#       8     sum += max(number)
# ----> 9     number = number.pop(max(number))
#
# IndexError: pop index out of range

# %%
def solution(n):
    number = [i for i in str(n)]
    number_ = sorted(number, reverse=True)
    
    return int(''.join(number_))

# %%
def solution(n):
    return int(''.join(sorted(str(n), reverse=True)))
