# %% [markdown]
# ![image.png](attachment:image.png)

# %%
C = int(input())

for i in range(C):
    score = list(map(int, input().split()))
    n = score[0]
    del score[0]
    av = sum(score)/n

    c =0
    for i in score:
        if av < i:
            c+=1
    rate = c/len(score)*100
    print(f'{rate:.3f}%')
# Out:
# 40.000%
# 33.333%
# 66.667%
