# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(n):
    answer = 1
    
    while n != 1:
        if n % 2 == 0:
            n /= 2

        else:
            n -= 1
            answer += 1

    return answer

# %% [markdown]
# 이런 문제는 뒤집어서 생각해보면 쉽게 풀릴때도 있음

# %%
5000 - 2500 - 1250 - 625 - 624* - 312 - 156 - 78 - 39 - 38* - 19 - 18* - 9 - 8* - 4 - 2 - 1* - 0

# %%
def solution(n):
    answer = 1
    while n > 1:
        answer += n % 2
        n = n // 2
    return answer
