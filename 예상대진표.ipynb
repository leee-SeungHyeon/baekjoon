# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(n,a,b):
    count = 0

    while a != b:

        a = (a + 1) //2
        b = (b + 1) //2

        count += 1

    return count

# %%
count = 0

while a != b:
    count += 1
    
    a = (a + 1) //2 
    b = (b + 1) //2 
    
    
return count
# Out:
# 1
# 2 4
# 2
# 1 2
# 3
# 1 1

# %%
a
# Out:
# 1

# %%
b
# Out:
# 1

# %%
count
# Out:
# 3
