# %% [markdown]
# ![image.png](attachment:image.png)

# %%
name = input()

result = ''

for i in name:
    if i not in ['C','A','M','B','R','I','D','G','E']:
        result += i
        
print(result)
# Out:
# LOV
