# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(s):
    sss = []

    for i in s:
        if i == '(':
            sss.append(i)
        elif i == ')':
            if not sss or sss.pop() != '(': 
                return False
            
    return len(sss) == 0
