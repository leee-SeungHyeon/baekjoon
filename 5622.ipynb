# %% [markdown]
# ![image.png](attachment:image.png)

# %%
phone = ['ABC', 'DEF', 'GHI', 'JKL', 'MNO', 'PQRS', 'TUV', 'WXYZ']

timer = 0

ss = input()

for i in phone:#abc가 나옴
    for j in i:#a가 나옴
        for s in ss: #입력받은 문자 하나씩 나옴
            if j == s: 
                timer += phone.index(i) + 3
                
print(timer)
# Out:
# 13
