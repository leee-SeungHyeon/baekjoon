# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(n):
    while True:
        for i in range(1,n+1):
            if n%i==1:
                answer = i
                break
        break
    
    return answer
# Out:
# 3
