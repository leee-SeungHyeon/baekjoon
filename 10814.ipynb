# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m = int(input())

list1 = []

for i in range(m):
    
    a,b = input().split()
    
    list1.append((i,int(a),b))
    
list1.sort(key=lambda x: x[1])

for i in range(len(list1)):
    print(list1[i][1], list1[i][2])
# Out:
# 20 Sunyoung
# 21 Junkyu
# 21 Dohyun

# %% [markdown]
# - 순서대로 출력을 위해 list1에 i를 같이 넣어주는것이 포인트
