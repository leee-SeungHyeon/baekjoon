# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def factorial(n):
    if n <= 1:
        return 1
    else:
        return n * factorial(n-1)
        
n, k = map(int, input().split())

print(factorial(n)//(factorial(k)*factorial(n-k)))
# Out:
# 10

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - 팩토리얼 개념만 알면 다 풀 수 있는 문제
