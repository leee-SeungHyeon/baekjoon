# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a, b, c, d, e, f = map(int, input().split())

det = a * e - b * d

x = (c * e - b * f) // det
y = (a * f - c * d) // det

print(x, y)
# Out:
# 2 -1

# %% [markdown]
# ![image.png](attachment:image.png)
# - 해당 공식을 사용하면 연립방정식은 풀 수 있음
