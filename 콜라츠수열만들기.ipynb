# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(n):
    answer = []
    
    while True:
        answer.append(n)

        if n == 1:
            break

        if n % 2 == 0:
            n //= 2
        else:
            n = 3*n +1
    return answer

# %%
solution(10)
# Out:
# [10, 5, 16, 8, 4, 2, 1]
