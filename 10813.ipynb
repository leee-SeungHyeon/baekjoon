# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a, b = map(int, input().split())

busket = [i+1 for i in range(a)]

for n in range(b):
    i, j = map(int, input().split())
    k = busket[i-1]
    p = busket[j-1]
    
    busket[i-1] = p
    busket[j-1] = k
    
for i in busket:
    print(i, end=' ')
# Out:
# 1 [2, 1, 3, 4, 5]
# 2 [2, 1, 4, 3, 5]
# 3 [3, 1, 4, 2, 5]
# 4 [3, 1, 4, 2, 5]
# 3 1 4 2 5
