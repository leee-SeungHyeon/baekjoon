# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(arr1, arr2):
    
    matrix = []
    
    for i in range(len(arr1)):
        matrix_ = []
        for j in range(len(arr1[0])):
            matrix_.append(arr1[i][j] + arr2[i][j])
        matrix.append(matrix_)

    return matrix
