# %% [markdown]
# ![image.png](attachment:image.png)

# %%
while True:
    n = input()
    
    if n == '0':
        break
    
    n1 = n[::-1]

    if n1 == n:
        print('yes')
    else:
        print('no')
# Out:
# yes
# no
# yes
