# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = input()

st = set()
for i in range(len(s)):
    for j in range(i,len(s)):
        ss = s[i:j+1]
        st.add(ss)

print(len(st))
# Out:
# 12
