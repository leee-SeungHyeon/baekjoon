# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N, m, M, T, R = map(int, input().split())

total = time = 0

hp = m

if m+T>M:
    print(-1)

else:
    while(time < N):
        if hp + T <= M:
            hp += T
            time += 1
        else:
            hp = max(hp-R, m)
            
        total += 1

    print(total)
# Out:
# 10
