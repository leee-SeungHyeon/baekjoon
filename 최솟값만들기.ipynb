# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(A,B):
    
    sum = 0
    
    A.sort()
    B.sort(reverse=True)
    
    for a, b in zip(A, B):
        sum += a*b
    
    return sum
