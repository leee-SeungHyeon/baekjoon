# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(num_list):
    
    mm = 1
    for i in num_list:
        mm *= i

    if mm < sum(num_list)**2:
        return 1
    else:
        return 0
# Out:
# 0
