# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())

prime_num = []

i = 2

while i <= n:
    if n%i == 0:
        prime_num.append(i)
        n = n//i
    
    else:
        i += 1
        
for j in prime_num:
    print(j)
# Out:
# 3
